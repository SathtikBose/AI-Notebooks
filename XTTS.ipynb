# %%
# !git clone https://github.com/SWivid/F5-TTS.git
# Out:
# Cloning into 'F5-TTS'...
# remote: Enumerating objects: 4026, done.
# remote: Counting objects: 100% (1232/1232), done.
# remote: Compressing objects: 100% (296/296), done.
# remote: Total 4026 (delta 1063), reused 936 (delta 936), pack-reused 2794 (from 2)
# Receiving objects: 100% (4026/4026), 2.37 MiB | 6.01 MiB/s, done.
# Resolving deltas: 100% (2463/2463), done.

# %%
# %cd F5-TTS
# !pip install -e .
# Out:
# [Errno 2] No such file or directory: 'F5-TTS'
# /content/F5-TTS
# Obtaining file:///content/F5-TTS
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.7/104.7 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 71.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.5/155.5 kB 16.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.2/840.2 kB 50.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 93.0 MB/s eta 0:00:00
# ...

# %%
# !f5-tts_infer-gradio --share
# Out:
# object address  : 0x7d51f7687220
# object refcount : 3
# object type     : 0xa284e0
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
# Traceback (most recent call last):
# ^C
